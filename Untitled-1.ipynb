# %%
pip install evaluate transformers torch ollama
# Out:
# ...
#      ---------------------------------------- 0.0/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/84.1 kB ? eta -:--:--
# ...
